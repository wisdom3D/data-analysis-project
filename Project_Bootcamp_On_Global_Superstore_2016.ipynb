# %% [markdown]
# <a href="https://colab.research.google.com/github/wisdom3D/data-analysis-project/blob/main/Project_Bootcamp_On_Global_Superstore_2016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project_On
# # Global Superstore 2016
# #wisdom KOUDAMA

# %% [markdown]
# # Aim:

# %% [markdown]
# #### The aim of this project is to analyse the data with respect to the sales and profit after filtering some of the columns.

# %% [markdown]
# ### Project Questions:

# %% [markdown]
# 1. Total, how many orders have cross the shipping cost of 500?

# %% [markdown]
# 2. Count the number of segments, countries, regions, markets, categories, and sub-categories present in the global_superstore_2016 data.

# %% [markdown]
# 3. Get the list of Order ID's where the Indian customer's have bought the things under the category 'Technology' after paying the Shipping Cost more than 500.

# %% [markdown]
# 4. Get the list of Order ID's where the Indian customer's have bought the things under the category 'Technology' the Sales greater than 500.

# %% [markdown]
# 5. How many people from the State 'Karnataka' have bought the things under the category 'Technology'?

# %% [markdown]
# 6. Get the list of countries where the 'Profit' and 'Shipping Cost's are greater than or equal to 2000 and 300 respectively.

# %% [markdown]
# 7. Find the list of Indian states where the people have purchased the things under the category Technology.

# %% [markdown]
# 8. Find the overall rank of "India" where the 'Profit' is maximum under the category 'Technology'.

# %% [markdown]
# 9. Display the data with min, max, average and std of 'Profit' & 'Sales' for each Sub-Category under each Category

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('/content/global_superstore_2016.xls')

# %%
data.head(2)
# Out:
#    Row ID                  Order ID           Order Date            Ship Date  \
# 0   40098  CA-2014-AB10015140-41954  2014-11-11 00:00:00           11/13/2014
# 1   26341    IN-2014-JR162107-41675  2014-05-02 00:00:00  2014-07-02 00:00:00
#
#       Ship Mode   Customer ID  Customer Name    Segment  Postal Code  \
# 0   First Class  AB-100151402  Aaron Bergman   Consumer      73120.0
# 1  Second Class     JR-162107  Justin Ritter  Corporate          NaN
#
#             City  ...   Product ID    Category Sub-Category  \
# 0  Oklahoma City  ...  TEC-PH-5816  Technology       Phones
# 1     Wollongong  ...  FUR-CH-5379   Furniture       Chairs
#
#                                 Product Name       Sales Quantity Discount  \
# 0                           Samsung Convoy 3    $221.98       2.0      0.0
# 1  Novimex Executive Leather Armchair, Black  $3,709.40       9.0      0.1
#
#       Profit Shipping Cost  Order Priority
# 0    $62.15          40.77            High
# 1  ($288.77)        923.63        Critical
#
# [2 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
#  17  Product Name    51290 non-null  object
#  18  Sales           51284 non-null  object
#  19  Quantity        51284 non-null  float64
#  20  Discount        51284 non-null  float64
#  21  Profit          51284 non-null  object
#  22  Shipping Cost   51284 non-null  float64
#  23  Order Priority  51284 non-null  object
# dtypes: float64(4), int64(1), object(19)
# memory usage: 9.4+ MB

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])

# %%
data['Ship Date'] = pd.to_datetime(data['Ship Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
#  17  Product Name    51290 non-null  object
#  18  Sales           51284 non-null  object
#  19  Quantity        51284 non-null  float64
#  20  Discount        51284 non-null  float64
#  21  Profit          51284 non-null  object
#  22  Shipping Cost   51284 non-null  float64
#  23  Order Priority  51284 non-null  object
# dtypes: datetime64[ns](2), float64(4), int64(1), object(17)
# memory usage: 9.4+ MB

# %%
data.drop(columns = ['Row ID', 'Customer ID', 'Postal Code'], inplace = True)

# %%
data.head(1)
# Out:
#                    Order ID Order Date  Ship Date    Ship Mode  Customer Name  \
# 0  CA-2014-AB10015140-41954 2014-11-11 2014-11-13  First Class  Aaron Bergman
#
#     Segment           City     State        Country      Region  ...  \
# 0  Consumer  Oklahoma City  Oklahoma  United States  Central US  ...
#
#     Product ID    Category Sub-Category      Product Name     Sales Quantity  \
# 0  TEC-PH-5816  Technology       Phones  Samsung Convoy 3  $221.98       2.0
#
#    Discount   Profit Shipping Cost  Order Priority
# 0       0.0  $62.15          40.77            High
#
# [1 rows x 21 columns]

# %%
if data['Sales'].str.contains('$').any():
   print("present")
# Out:
# present

# %%
if data['Profit'].str.contains('$').any():
  print("yes")
# Out:
# yes

# %%
data['Sales'] = data['Sales'].str.replace('$', '', regex = True)
data['Sales'][:10]
# Out:
# 0      221.98
# 1    3,709.40
# 2    5,175.17
# 3    2,892.51
# 4    2,832.96
# 5    2,862.68
# 6    1,822.08
# 7    5,244.84
# 8      341.96
# 9       48.71
# Name: Sales, dtype: object

# %%
data['Sales'] = data['Sales'].str.replace(',', '', regex = True)
data['Sales'][:10]
# Out:
# 0     221.98
# 1    3709.40
# 2    5175.17
# 3    2892.51
# 4    2832.96
# 5    2862.68
# 6    1822.08
# 7    5244.84
# 8     341.96
# 9      48.71
# Name: Sales, dtype: object

# %%
data['Profit'] = data['Profit'].str.replace(',', '', regex = True)
data['Profit'][:10]
# Out:
# 0      $62.15
# 1    ($288.77)
# 2     $919.97
# 3     ($96.54)
# 4     $311.52
# 5     $763.28
# 6     $564.84
# 7     $996.48
# 8      $54.71
# 9       $5.48
# Name: Profit, dtype: object

# %%
data['Profit'] = data['Profit'].str.replace('$', '', regex = True)
data['Profit'][:10]
# Out:
# 0      62.15
# 1    (288.77)
# 2     919.97
# 3     (96.54)
# 4     311.52
# 5     763.28
# 6     564.84
# 7     996.48
# 8      54.71
# 9       5.48
# Name: Profit, dtype: object

# %%
data['Profit'] = data['Profit'].str.replace('(', '', regex = True)
data['Profit'][:10]
# Out:
# 0     62.15
# 1    288.77)
# 2    919.97
# 3     96.54)
# 4    311.52
# 5    763.28
# 6    564.84
# 7    996.48
# 8     54.71
# 9      5.48
# Name: Profit, dtype: object

# %%
data['Profit'] = data['Profit'].str.replace(')', '', regex = True)
data['Profit'][:20]
# Out:
# 0       62.15
# 1       288.77
# 2      919.97
# 3        96.54
# 4      311.52
# 5      763.28
# 6      564.84
# 7      996.48
# 8       54.71
# 9        5.48
# 10       4.66
# 11     647.55
# 12    1151.40
# 13     622.02
# 14    1036.08
# 15     186.95
# 16        2.52
# 17    3979.08
# 18      28.40
# 19     818.28
# Name: Profit, dtype: object

# %%
data['Profit'] = data['Profit'].astype(np.float64)

# %%
data.head(1)
# Out:
#                    Order ID Order Date  Ship Date    Ship Mode  Customer Name  \
# 0  CA-2014-AB10015140-41954 2014-11-11 2014-11-13  First Class  Aaron Bergman
#
#     Segment           City     State        Country      Region  ...  \
# 0  Consumer  Oklahoma City  Oklahoma  United States  Central US  ...
#
#     Product ID    Category Sub-Category      Product Name    Sales Quantity  \
# 0  TEC-PH-5816  Technology       Phones  Samsung Convoy 3  221.98       2.0
#
#    Discount  Profit  Shipping Cost  Order Priority
# 0       0.0   62.15          40.77            High
#
# [1 rows x 21 columns]

# %% [markdown]
# **Total, how many orders have cross the shipping cost of 500?**

# %%
len(data[data['Shipping Cost'] > 500])
# Out:
# 120

# %%
data[data['Shipping Cost'] > 500].shape[0]
# Out:
# 120

# %% [markdown]
# **Count the number of segments, countries, regions, markets, categories, and sub-categories present in the global_superstore_2016 data.**

# %%
data[['Segment']].value_counts()
# Out:
# Segment
# Consumer       26518
# Corporate      15429
# Home Office     9343
# dtype: int64

# %%
data[['Country']].value_counts()
# Out:
# Country
# United States    9994
# Australia        2837
# France           2827
# Mexico           2635
# Germany          2063
#                  ...
# Suriname            1
# Kuwait              1
# Malawi              1
# The Gambia          1
# Bhutan              1
# Length: 165, dtype: int64

# %%
data[[ 'Region']].value_counts()
# Out:
# Region
# Western Europe       5883
# Central America      5616
# Oceania              3487
# Western US           3203
# Southeastern Asia    3129
# South America        2988
# Eastern US           2848
# Southern Asia        2655
# Western Asia         2440
# Eastern Asia         2374
# Central US           2323
# Northern Europe      2204
# Southern Europe      2113
# Caribbean            1690
# Southern US          1620
# Eastern Europe       1529
# Western Africa       1460
# North Africa         1278
# Eastern Africa        728
# Central Africa        643
# Southern Africa       478
# Canada                384
# Central Asia          217
# dtype: int64

# %%
data[['Market']].value_counts()
# Out:
# Market
# Asia Pacific    14302
# Europe          11729
# USCA            10378
# LATAM           10294
# Africa           4587
# dtype: int64

# %%
data[[ 'Category']].value_counts()
# Out:
# Category
# Office Supplies    31289
# Technology         10141
# Furniture           9860
# dtype: int64

# %%
data[['Sub-Category']].value_counts()
# Out:
# Sub-Category
# Binders         6146
# Storage         5049
# Art             4864
# Paper           3492
# Chairs          3434
# Phones          3357
# Furnishings     3154
# Accessories     3075
# Labels          2601
# Fasteners       2601
# Bookcases       2411
# Supplies        2407
# Envelopes       2387
# Copiers         2223
# Appliances      1742
# Machines        1486
# Tables           861
# dtype: int64

# %%
data[['Segment', 'Country', 'Region','Market', 'Category', 'Sub-Category']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Segment       51290 non-null  object
#  1   Country       51290 non-null  object
#  2   Region        51290 non-null  object
#  3   Market        51290 non-null  object
#  4   Category      51290 non-null  object
#  5   Sub-Category  51290 non-null  object
# dtypes: object(6)
# memory usage: 2.3+ MB

# %% [markdown]
# **Get the list of Order ID's where the Indian customer's have bought the things under the category 'Technology' after paying the Shipping Cost more than 500.**

# %%
data1 = data.query("(Country == 'India') & (Category == 'Technology') ")
sol = data1[data1['Shipping Cost'] >= 500]['Order ID']
sol.tolist()
# Out:
# ['IN-2015-BF1100558-42319',
#  'IN-2015-SW2027558-42125',
#  'IN-2013-SG2047058-41424',
#  'IN-2013-GP1474058-41419']

# %% [markdown]
# **Get the list of Order ID's where the Indian customer's have bought the things under the category 'Technology' the Sales greater than 500.**

# %%
data['Sales'] = data['Sales'].astype(np.float64)

# %%
data2 = data.query("(Country == 'India') & (Category == 'Technology') ")
data2[data2['Sales'] > 500]['Order ID']
# Out:
# 41       IN-2015-BF1100558-42319
# 48       IN-2015-SW2027558-42125
# 55       IN-2013-SG2047058-41424
# 90       IN-2013-GP1474058-41419
# 130      IN-2014-SV2081558-41968
#                   ...
# 14874    IN-2013-ML1826558-41503
# 15236    IN-2015-HG1484558-42339
# 23250    IN-2013-MA1799558-41565
# 24316    IN-2012-DP1316558-41173
# 35903    IN-2013-JS1568558-41371
# Name: Order ID, Length: 163, dtype: object

# %% [markdown]
# **How many people from the State 'Karnataka' have bought the things under the category 'Technology'?**

# %%
data3 = data[(data['State'] == 'Karnataka')]
len(data3[data3['Category'] == 'Technology'])
# Out:
# 21

# %%
data3 = data[(data['Country'] == 'India') &  (data['State'] == 'Karnataka')]
len(data3[data3['Category'] == 'Technology'])
# Out:
# 21

# %% [markdown]
# **Get the list of countries where the 'Profit' and 'Shipping Cost's are greater than or equal to 2000 and 300 respectively.**

# %%
data4 = data[data['Profit'] >= 2000]
data4[data4['Shipping Cost'] >= 300]
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 17      ES-2015-PJ1883564-42255 2015-08-09 2015-09-14  Standard Class
# 42      IN-2015-VG2180558-42273 2015-09-26 2015-09-28    Second Class
# 81       MO-2015-DP310586-42305 2015-10-28 2015-10-30    Second Class
# 109     IT-2014-VM2168591-41711 2014-03-13 2014-03-13        Same Day
# 192    ES-2014-JG15160139-41660 2014-01-21 2014-01-24    Second Class
# 215     ID-2012-CA1196566-40949 2012-10-02 2012-02-15  Standard Class
# 245      LH-2015-JC610575-42032 2015-01-28 2015-01-30    Second Class
# 313     IN-2014-CA1277558-41802 2014-12-06 2014-06-17  Standard Class
# 334      IN-2015-MB173057-42179 2015-06-24 2015-06-28  Standard Class
# 362     ID-2014-SN2056097-41896 2014-09-14 2014-09-14        Same Day
# 419    CA-2014-AB10105140-41991 2014-12-18 2014-12-22  Standard Class
# 2257   CA-2015-AR10540140-42021 2015-01-17 2015-01-19    Second Class
# 6422   US-2014-BS11365140-41746 2014-04-17 2014-04-21  Standard Class
# 11123  CA-2013-CM12385140-41349 2013-03-16 2013-03-22  Standard Class
# 11755  CA-2014-CS12505140-41969 2014-11-26 2014-03-12  Standard Class
# 23110  US-2015-GT14635140-42313 2015-05-11 2015-05-11        Same Day
# 24214  US-2013-HM14860140-41632 2013-12-24 2013-12-30  Standard Class
# 25238  CA-2015-HL15040140-42326 2015-11-18 2015-11-23  Standard Class
# 31453  US-2014-KD16270140-41700 2014-02-03 2014-06-03  Standard Class
# 32753  CA-2013-KD16495140-41586 2013-08-11 2013-08-11        Same Day
# 46295  CA-2012-SC20095140-41174 2012-09-22 2012-09-27  Standard Class
# 49003  CA-2014-TC20980140-41915 2014-03-10 2014-10-10  Standard Class
# 49968  CA-2012-TB21400140-41256 2012-12-13 2012-12-20  Standard Class
#
#               Customer Name      Segment                City  \
# 17            Patrick Jones    Corporate               Prato
# 42              Vivek Grady    Corporate  Thiruvananthapuram
# 81             Dave Poirier    Corporate              Meknes
# 109         Valerie Mitchum  Home Office      Bergen op Zoom
# 192            James Galang     Consumer    Stockton-on-Tees
# 215             Carol Adams    Corporate                Fuji
# 245         Julie Creighton    Corporate             Vilnius
# 313         Cynthia Arntzen     Consumer                Kota
# 334         Maria Bertelson     Consumer              Sydney
# 362            Skye Norling  Home Office              Lahore
# 419           Adrian Barton     Consumer             Detroit
# 2257            Andy Reiter     Consumer             Jackson
# 6422           Bill Shonely    Corporate            Lakewood
# 11123  Christopher Martinez     Consumer             Atlanta
# 11755         Cindy Stewart     Consumer           Lancaster
# 23110        Grant Thornton    Corporate          Burlington
# 24214           Harry Marie    Corporate         Springfield
# 25238          Hunter Lopez     Consumer              Newark
# 31453         Karen Daniels     Consumer             Yonkers
# 32753         Keith Dawkins    Corporate       New York City
# 46295          Sanjit Chand     Consumer         Minneapolis
# 49003          Tamara Chand    Corporate           Lafayette
# 49968      Tom Boeckenhauer     Consumer       New York City
#
#                   State         Country           Region  ...   Product ID  \
# 17              Tuscany           Italy  Southern Europe  ...  OFF-AP-4743
# 42               Kerala           India    Southern Asia  ...  FUR-BO-5951
# 81     Meknès-Tafilalet         Morocco     North Africa  ...  TEC-CO-3710
# 109       North Brabant     Netherlands   Western Europe  ...  FUR-CH-5442
# 192             England  United Kingdom  Northern Europe  ...  FUR-TA-3344
# 215            Shizuoka           Japan     Eastern Asia  ...  TEC-PH-5841
# 245             Vilnius       Lithuania  Northern Europe  ...  FUR-TA-3345
# 313        Chhattisgarh           India    Southern Asia  ...  TEC-PH-3149
# 334     New South Wales       Australia          Oceania  ...  FUR-BO-5948
# 362              Punjab        Pakistan    Southern Asia  ...  TEC-PH-3148
# 419            Michigan   United States       Central US  ...  OFF-BI-4345
# 2257           Michigan   United States       Central US  ...  OFF-BI-4340
# 6422         New Jersey   United States       Eastern US  ...  TEC-MA-2865
# 11123           Georgia   United States      Southern US  ...  OFF-BI-4276
# 11755              Ohio   United States       Eastern US  ...  TEC-MA-3854
# 23110    North Carolina   United States      Southern US  ...  TEC-MA-3855
# 24214          Missouri   United States       Central US  ...  TEC-CO-3698
# 25238          Delaware   United States       Eastern US  ...  TEC-CO-3691
# 31453          New York   United States       Eastern US  ...  TEC-MA-3173
# 32753          New York   United States       Eastern US  ...  TEC-MA-6633
# 46295         Minnesota   United States       Central US  ...  OFF-BI-4821
# 49003           Indiana   United States       Central US  ...  TEC-CO-3691
# 49968          New York   United States       Eastern US  ...  TEC-MA-4768
#
#               Category Sub-Category  \
# 17     Office Supplies   Appliances
# 42           Furniture    Bookcases
# 81          Technology      Copiers
# 109          Furniture       Chairs
# 192          Furniture       Tables
# 215         Technology       Phones
# 245          Furniture       Tables
# 313         Technology       Phones
# 334          Furniture    Bookcases
# 362         Technology       Phones
# 419    Office Supplies      Binders
# 2257   Office Supplies      Binders
# 6422        Technology     Machines
# 11123  Office Supplies      Binders
# 11755       Technology     Machines
# 23110       Technology     Machines
# 24214       Technology      Copiers
# 25238       Technology      Copiers
# 31453       Technology     Machines
# 32753       Technology     Machines
# 46295  Office Supplies      Binders
# 49003       Technology      Copiers
# 49968       Technology     Machines
#
#                                             Product Name     Sales  Quantity  \
# 17                                     Hoover Stove, Red   7958.58      14.0
# 42                  Sauder Classic Bookcase, Traditional   5667.87      13.0
# 81                             Canon Wireless Fax, Laser   5301.24      14.0
# 109        Office Star Executive Leather Armchair, Black   2570.87      11.0
# 192           Barricks Conference Table, Fully Assembled   5451.30       6.0
# 215                            Samsung Smart Phone, VoIP   6998.64      11.0
# 245               Barricks Conference Table, Rectangular   2171.16       8.0
# 313                    Apple Smart Phone, with Caller ID   5751.54       9.0
# 334                       Sauder Classic Bookcase, Metal   5486.67      14.0
# 362                         Apple Smart Phone, Full Size   3499.16      11.0
# 419     GBC Ibimaster 500 Manual ProClick Binding System   9892.74      13.0
# 2257           GBC DocuBind P400 Electric Binding System   5443.96       4.0
# 6422    3D Systems Cube Printer, 2nd Generation, Magenta   9099.93       7.0
# 11123  Fellowes PB500 Electric Punch Plastic Comb Bin...   6354.95       5.0
# 11755          Cubify CubeX 3D Printer Double Head Print   4499.99       5.0
# 23110          Cubify CubeX 3D Printer Triple Head Print   7999.98       4.0
# 24214                 Canon PC1060 Personal Laser Copier   4899.93       7.0
# 25238              Canon imageCLASS 2200 Advanced Copier  10499.97       3.0
# 31453                  Ativa V4110MDD Micro-Cut Shredder   4899.93       7.0
# 32753                  Zebra ZM400 Thermal Label Printer   4643.80       4.0
# 46295               Ibico EPK-21 Electric Binding System   9449.95       5.0
# 49003              Canon imageCLASS 2200 Advanced Copier  17499.95       5.0
# 49968  HP Designjet T520 Inkjet Large Format Printer ...   6999.96       4.0
#
#        Discount   Profit  Shipping Cost  Order Priority
# 17          0.0  3979.08         778.32             Low
# 42          0.0  2097.03         658.35          Medium
# 81          0.0  2597.28         568.45          Medium
# 109         0.5  2211.17         520.89            High
# 192         0.0  2071.44         432.13          Medium
# 215         0.0  2939.31         413.80          Medium
# 245         0.7  2750.28         390.09            High
# 313         0.0  2817.99         353.85          Medium
# 334         0.1  2316.51         346.60          Medium
# 362         0.5  3009.44         333.10          Medium
# 419         0.0  4946.37         498.70          Medium
# 2257        0.0  2504.22         567.95            High
# 6422        0.0  2365.98         516.91          Medium
# 11123       0.0  3177.48         581.12          Medium
# 11755       0.7  6599.98         451.63             Low
# 23110       0.5  3839.99         674.82            High
# 24214       0.0  2302.97         350.09          Medium
# 25238       0.0  5039.99         363.19          Medium
# 31453       0.0  2400.97         466.33          Medium
# 32753       0.0  2229.02         607.34          Medium
# 46295       0.0  4630.48         655.61          Medium
# 49003       0.0  8399.98         349.07          Medium
# 49968       0.0  2239.99         499.55          Medium
#
# [23 rows x 21 columns]

# %%
data4['Country'].drop_duplicates().to_list()
# Out:
# ['Italy',
#  'India',
#  'Morocco',
#  'Netherlands',
#  'United Kingdom',
#  'Japan',
#  'Lithuania',
#  'Australia',
#  'Pakistan',
#  'United States',
#  'Portugal',
#  'New Zealand',
#  'Turkey',
#  'Spain']

# %% [markdown]
# **Find the list of Indian states where the people have purchased the things under the category Technology.**

# %%
data5 = data[data['Country'] == 'India']
data5[data5['Category'] == 'Technology']
# Out:
#                       Order ID Order Date  Ship Date       Ship Mode  \
# 41     IN-2015-BF1100558-42319 2015-11-11 2015-11-15  Standard Class
# 48     IN-2015-SW2027558-42125 2015-01-05 2015-01-05        Same Day
# 55     IN-2013-SG2047058-41424 2013-05-30 2013-05-31     First Class
# 90     IN-2013-GP1474058-41419 2013-05-25 2013-05-28    Second Class
# 130    IN-2014-SV2081558-41968 2014-11-25 2014-11-27     First Class
# ...                        ...        ...        ...             ...
# 39631  IN-2013-JR1570058-41441 2013-06-16 2013-06-22  Standard Class
# 40262  IN-2014-GZ1447058-41721 2014-03-23 2014-03-27  Standard Class
# 42345  IN-2015-CR1282058-42294 2015-10-17 2015-10-21  Standard Class
# 43976  IN-2015-LD1700558-42101 2015-07-04 2015-11-04  Standard Class
# 51172  IN-2014-AS1013558-41817 2014-06-27 2014-03-07  Standard Class
#
#           Customer Name      Segment        City           State Country  \
# 41          Barry Franz  Home Office   Gorakhpur         Haryana   India
# 48     Scott Williamson     Consumer  Jamshedpur       Jharkhand   India
# 55         Sheri Gordon     Consumer      Bhopal  Madhya Pradesh   India
# 90          Guy Phonely    Corporate       Delhi           Delhi   India
# 130          Stuart Van    Corporate    Vadodara         Gujarat   India
# ...                 ...          ...         ...             ...     ...
# 39631    Jocasta Rupert     Consumer      Kollam          Kerala   India
# 40262     Gary Zandusky     Consumer    Ludhiana          Punjab   India
# 42345       Cyra Reiten  Home Office       Patna           Bihar   India
# 43976    Lisa DeCherney     Consumer  Kukatpalli       Telangana   India
# 51172      Adrian Shami  Home Office   Nagercoil      Tamil Nadu   India
#
#               Region  ...   Product ID    Category Sub-Category  \
# 41     Southern Asia  ...  TEC-PH-5269  Technology       Phones
# 48     Southern Asia  ...  TEC-MA-5007  Technology     Machines
# 55     Southern Asia  ...  TEC-CO-4590  Technology      Copiers
# 90     Southern Asia  ...  TEC-PH-5356  Technology       Phones
# 130    Southern Asia  ...  TEC-CO-4577  Technology      Copiers
# ...              ...  ...          ...         ...          ...
# 39631  Southern Asia  ...  TEC-AC-4178  Technology  Accessories
# 40262  Southern Asia  ...  TEC-AC-5221  Technology  Accessories
# 42345  Southern Asia  ...  TEC-PH-5838  Technology       Phones
# 43976  Southern Asia  ...  TEC-CO-3591  Technology      Copiers
# 51172  Southern Asia  ...  TEC-AC-3388  Technology  Accessories
#
#                                  Product Name    Sales  Quantity  Discount  \
# 41       Motorola Smart Phone, with Caller ID  4518.78       7.0       0.0
# 48                       Konica Inkjet, White  2174.13       7.0       0.0
# 55                Hewlett Wireless Fax, Color  1526.52       4.0       0.0
# 90          Nokia Smart Phone, with Caller ID  1916.73       3.0       0.0
# 130           Hewlett Fax Machine, High-Speed  1590.60       5.0       0.0
# ...                                       ...      ...       ...       ...
# 39631       Enermax Numeric Keypad, Bluetooth   114.66       2.0       0.0
# 40262       Memorex Numeric Keypad, Erganomic    93.42       2.0       0.0
# 42345  Samsung Signal Booster, with Caller ID   136.59       1.0       0.0
# 43976           Brother Fax and Copier, Color   385.86       2.0       0.0
# 51172           Belkin Memory Card, Bluetooth   114.81       1.0       0.0
#
#        Profit  Shipping Cost  Order Priority
# 41     632.52         658.69            High
# 48     500.01         637.86        Critical
# 55     732.72         625.77        Critical
# 90     498.33         548.40        Critical
# 130    572.55         493.20        Critical
# ...       ...            ...             ...
# 39631    4.56           2.33          Medium
# 40262   42.96           2.18          Medium
# 42345   57.36           1.92            High
# 43976   84.84           1.77          Medium
# 51172   32.13           1.06          Medium
#
# [354 rows x 21 columns]

# %%
states = data5['State'].drop_duplicates().to_list()
len(states)
# Out:
# 25

# %% [markdown]
# **Find the overall rank of "India" where the 'Profit' is maximum under the category 'Technology'**

# %%
data5.sort_values(by = 'Profit', ascending = False)
# Out:
#                       Order ID Order Date  Ship Date       Ship Mode  \
# 313    IN-2014-CA1277558-41802 2014-12-06 2014-06-17  Standard Class
# 42     IN-2015-VG2180558-42273 2015-09-26 2015-09-28    Second Class
# 184    IN-2015-CP1234058-42202 2015-07-17 2015-07-20     First Class
# 808    IN-2015-DO1343558-42141 2015-05-17 2015-05-22    Second Class
# 782    IN-2015-JW1522058-42101 2015-07-04 2015-12-04  Standard Class
# ...                        ...        ...        ...             ...
# 29233  IN-2015-LD1700558-42101 2015-07-04 2015-11-04  Standard Class
# 16044  IN-2015-DW1319558-42320 2015-12-11 2015-11-13     First Class
# 37941  IN-2014-AC1061558-41808 2014-06-18 2014-06-22  Standard Class
# 42473  IN-2013-AH1007558-41474 2013-07-19 2013-07-25  Standard Class
# 45951  IN-2015-DJ1363058-42153 2015-05-29 2015-02-06    Second Class
#
#          Customer Name    Segment                City              State  \
# 313    Cynthia Arntzen   Consumer                Kota       Chhattisgarh
# 42         Vivek Grady  Corporate  Thiruvananthapuram             Kerala
# 184     Christine Phan  Corporate          Aurangabad              Bihar
# 808       Denny Ordway   Consumer            Srinagar  Jammu and Kashmir
# 782          Jane Waco  Corporate           Mangalore          Karnataka
# ...                ...        ...                 ...                ...
# 29233   Lisa DeCherney   Consumer          Kukatpalli          Telangana
# 16044     David Wiener  Corporate                Pune        Maharashtra
# 37941        Ann Chong  Corporate            Ludhiana             Punjab
# 42473        Adam Hart  Corporate           Faridabad            Haryana
# 45951      Doug Jacobs   Consumer              Guntur     Andhra Pradesh
#
#       Country         Region  ...   Product ID         Category Sub-Category  \
# 313     India  Southern Asia  ...  TEC-PH-3149       Technology       Phones
# 42      India  Southern Asia  ...  FUR-BO-5951        Furniture    Bookcases
# 184     India  Southern Asia  ...  OFF-AP-4502  Office Supplies   Appliances
# 808     India  Southern Asia  ...  FUR-TA-3431        Furniture       Tables
# 782     India  Southern Asia  ...  TEC-PH-3807       Technology       Phones
# ...       ...            ...  ...          ...              ...          ...
# 29233   India  Southern Asia  ...  TEC-AC-5883       Technology  Accessories
# 16044   India  Southern Asia  ...  OFF-BI-4815  Office Supplies      Binders
# 37941   India  Southern Asia  ...  OFF-AR-3546  Office Supplies          Art
# 42473   India  Southern Asia  ...  OFF-PA-5851  Office Supplies        Paper
# 45951   India  Southern Asia  ...  OFF-LA-4685  Office Supplies       Labels
#
#                                     Product Name    Sales  Quantity  Discount  \
# 313            Apple Smart Phone, with Caller ID  5751.54       9.0       0.0
# 42          Sauder Classic Bookcase, Traditional  5667.87      13.0       0.0
# 184             Hamilton Beach Refrigerator, Red  4001.04       8.0       0.0
# 808               Bevis Round Table, Rectangular  3094.56       6.0       0.0
# 782            Cisco Smart Phone, with Caller ID  3271.20       5.0       0.0
# ...                                          ...      ...       ...       ...
# 29233                         SanDisk Mouse, USB   154.08       4.0       0.0
# 16044               Ibico Binding Machine, Clear   101.76       2.0       0.0
# 37941                          Boston Pens, Blue    28.44       2.0       0.0
# 42473  SanDisk Computer Printout Paper, 8.5 x 11    67.86       2.0       0.0
# 45951           Hon Round Labels, 5000 Label Set    35.25       5.0       0.0
#
#         Profit  Shipping Cost  Order Priority
# 313    2817.99         353.85          Medium
# 42     2097.03         658.35          Medium
# 184    1440.24         439.65          Medium
# 808    1423.44         227.67          Medium
# 782    1341.15         232.45            High
# ...        ...            ...             ...
# 29233     0.00           5.86          Medium
# 16044     0.00          17.86        Critical
# 37941     0.00           2.75          Medium
# 42473     0.00           1.91          Medium
# 45951     0.00           1.58          Medium
#
# [1554 rows x 21 columns]

# %%
len(data5['Profit'])
# Out:
# 1554

# %%
len(data5[data5['Profit'] > 0])
# Out:
# 1522

# %% [markdown]
# **Display the data with min, max, average and std of 'Profit' & 'Sales' for each Sub-Category under each Category**

# %%
function = [('min_value', 'min'), ('max_value', 'max'), ('mean_value', 'mean'), ('std_value', 'std')]

# %%
data6 = data.groupby(by = 'Sub-Category')
data6['Profit', 'Sales'].agg(function)
# Out:
# <ipython-input-71-3e972c224c1a>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data6['Profit', 'Sales'].agg(function)
#                 Profit                                       Sales            \
#              min_value max_value  mean_value   std_value min_value max_value
# Sub-Category
# Accessories        0.0   1345.50   68.078478  115.069702      0.99   3449.88
# Appliances         0.0   3979.08  154.726515  273.611285      0.44   7958.58
# Art                0.0    371.23   20.795995   27.376060      1.34   1113.02
# Binders            0.0   4946.37   28.994784  151.740030      0.56   9892.74
# Bookcases          0.0   2316.51  151.313799  201.464319     35.49   5667.87
# Chairs             0.0   2211.17   96.845271  158.250662     13.55   5759.96
# Copiers            0.0   8399.98  180.685070  337.885306     35.46  17499.95
# Envelopes          0.0    279.36   21.188395   26.633151      1.63    604.66
# Fasteners          0.0    127.26   10.178531   11.610903      1.24    271.32
# Furnishings        0.0    561.96   32.919220   48.025021      1.89   1519.14
# Labels             0.0    385.38    8.654617   14.863848      1.67    786.48
# Machines           0.0   6599.98  145.500404  318.019250     11.51  22638.48
# Paper              0.0    352.30   22.540272   28.645818      3.38    733.95
# Phones             0.0   4088.38  121.999809  229.382876      2.97   6998.64
# Storage            0.0    802.17   51.603367   81.462674      2.80   2962.68
# Supplies           0.0   1049.34   24.472530   38.919895      2.92   8187.65
# Tables             0.0   2750.28  260.352021  316.342028     24.37   5451.30
#
#
#               mean_value   std_value
# Sub-Category
# Accessories   243.502887  327.493136
# Appliances    580.100896  798.680507
# Art            76.400843   82.090796
# Binders        75.149705  288.673033
# Bookcases     608.283928  602.487538
# Chairs        437.298241  535.097972
# Copiers       679.008776  821.101120
# Envelopes      70.891320   70.009550
# Fasteners      34.407993   29.317593
# Furnishings   122.116725  145.810487
# Labels         28.200903   34.178941
# Machines      524.266703  928.001009
# Paper          69.240455   74.755398
# Phones        508.437489  717.305537
# Storage       223.175635  292.236933
# Supplies      100.877084  272.156490
# Tables        879.259199  796.402515
