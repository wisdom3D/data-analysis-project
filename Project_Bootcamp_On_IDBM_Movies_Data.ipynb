# %% [markdown]
# <a href="https://colab.research.google.com/github/wisdom3D/data-analysis-project/blob/main/Project_Bootcamp_On_IDBM_Movies_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project_On
# # IDBM_Movie_Data:
# #wisdom KOUDAMA

# %% [markdown]
# ## Aim:
#
# ### The aim of the project is to analyze the IDBM_Movie_Data with the following details:

# %% [markdown]
# #### Load the data into your working area and get the information about the null values.

# %% [markdown]
# #### Rename the columns for the analysis purpose if any columns are not in proper way.

# %% [markdown]
# #### Handle the missing value columns with the proper assumtion.

# %% [markdown]
# ####  Generate the relationship between each continuous variable using corr() method.

# %% [markdown]
# ####  Find the movies directed by 'James Gunn', & 'Ridley Scott' with the rating greater than or equal to 8.

# %% [markdown]
# ####  Display all the movies directed by 'Ridley Scott'.

# %% [markdown]
# ####  Display all the director's who got the rating >= 8 for their movies.

# %% [markdown]
# ####  Find all the movies directed by 'James Gunn', & 'Ridley Scott'.

# %% [markdown]
# ####  Display all the movies with the ratings between 8 & 9 and also the films with the highest rating.

# %% [markdown]
# ####  Find the movies directed by both 'Christopher Nolan' and 'Ridley Scott'

# %% [markdown]
# ####  Find all movies that were released between 2006 and 2010, have a rating above 8.0, but made below the 50th percentile in revenue.

# %% [markdown]
# ####  Find all movies that were released between 2006 and 2010, have a rating above 8.0, but made below the 25th percentile in revenue.

# %% [markdown]
# #### Finally give the feedback for all movies with 'Good' if the movie 'rating' is >= 8 and 'Average' if the movie rating doesn't follow the condition given.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Load the data into your working area and get the information about the null values.**

# %%
data = pd.read_csv('/content/IMDB_Movie_Data.csv')

# %%
data.head(2)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# **Rename the columns for the analysis purpose if any columns are not in proper way.**

# %%
data.rename(columns = {'Revenue (Millions)' : 'Revenue'}, inplace = True)

# %%
data.head(2)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
#
#    Rating   Votes  Revenue  Metascore
# 0     8.1  757074   333.13       76.0
# 1     7.0  485820   126.46       65.0

# %% [markdown]
# **Handle the missing value columns with the proper assumtion.**

# %%
data.dropna(axis = 0)
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# 2    Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4    A secret government agency recruits some of th...            David Ayer
# ..                                                 ...                   ...
# 993  While still out to destroy the evil Umbrella C...    Paul W.S. Anderson
# 994  3 high school seniors throw a birthday party t...       Nima Nourizadeh
# 996  Three American college students studying abroa...              Eli Roth
# 997  Romantic sparks occur between two dance studen...            Jon M. Chu
# 999  A stuffy businessman finds himself trapped ins...      Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
# ..                                                 ...   ...
# 993  Milla Jovovich, Ali Larter, Wentworth Miller,K...  2010
# 994  Thomas Mann, Oliver Cooper, Jonathan Daniel Br...  2012
# 996  Lauren German, Heather Matarazzo, Bijou Philli...  2007
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating   Votes  Revenue  Metascore
# 0                  121     8.1  757074   333.13       76.0
# 1                  124     7.0  485820   126.46       65.0
# 2                  117     7.3  157606   138.12       62.0
# 3                  108     7.2   60545   270.32       59.0
# 4                  123     6.2  393727   325.02       40.0
# ..                 ...     ...     ...      ...        ...
# 993                 97     5.9  140900    60.13       37.0
# 994                 88     6.7  164088    54.72       48.0
# 996                 94     5.5   73152    17.54       46.0
# 997                 98     6.2   70699    58.01       50.0
# 999                 87     5.3   12435    19.64       11.0
#
# [838 rows x 12 columns]

# %% [markdown]
# **Generate the relationship between each continuous variable using corr() method.**

# %%
continuous = data[['Rank', 'Year', 'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue', 'Metascore']]

# %%
continuous.corr()
# Out:
#                        Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank               1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# Year              -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# Runtime (Minutes) -0.221739 -0.164900           1.000000  0.392214  0.407062
# Rating            -0.219555 -0.211219           0.392214  1.000000  0.511537
# Votes             -0.283876 -0.411904           0.407062  0.511537  1.000000
# Revenue           -0.271592 -0.126790           0.267953  0.217654  0.639661
# Metascore         -0.191869 -0.079305           0.211978  0.631897  0.325684
#
#                     Revenue  Metascore
# Rank              -0.271592  -0.191869
# Year              -0.126790  -0.079305
# Runtime (Minutes)  0.267953   0.211978
# Rating             0.217654   0.631897
# Votes              0.639661   0.325684
# Revenue            1.000000   0.142397
# Metascore          0.142397   1.000000

# %% [markdown]
# **Find the movies directed by 'James Gunn', & 'Ridley Scott' with the rating greater than or equal to 8.**

# %%
data['Director'].unique()

# %%
james = data[data['Director'] == 'James Gunn']
james[james['Rating'] >= 8]
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue  Metascore
# 0     8.1  757074   333.13       76.0

# %%
Ridley = data[data['Director'] == 'Ridley Scott']
Ridley[Ridley['Rating'] >= 8]
# Out:
#      Rank        Title                   Genre  \
# 102   103  The Martian  Adventure,Drama,Sci-Fi
#
#                                            Description      Director  \
# 102  An astronaut becomes stranded on Mars after hi...  Ridley Scott
#
#                                                 Actors  Year  \
# 102  Matt Damon, Jessica Chastain, Kristen Wiig, Ka...  2015
#
#      Runtime (Minutes)  Rating   Votes  Revenue  Metascore
# 102                144     8.0  556097   228.43       80.0

# %% [markdown]
# **Display all the movies directed by 'Ridley Scott'.**

# %%
data[data['Director'] == 'Ridley Scott']['Title']
# Out:
# 1                  Prometheus
# 102               The Martian
# 387                Robin Hood
# 470         American Gangster
# 516    Exodus: Gods and Kings
# 521             The Counselor
# 530               A Good Year
# 737              Body of Lies
# Name: Title, dtype: object

# %% [markdown]
# **Display all the director's who got the rating >= 8 for their movies.**

# %%
data[data['Rating'] >= 8]['Director'].drop_duplicates()
# Out:
# 0                James Gunn
# 6           Damien Chazelle
# 16               Mel Gibson
# 18              Garth Davis
# 19         Denis Villeneuve
#                ...
# 695         Lasse Hallström
# 742    Juan José Campanella
# 772            Dean DeBlois
# 861            Naoko Yamada
# 991              Aamir Khan
# Name: Director, Length: 65, dtype: object

# %% [markdown]
# **Find all the movies directed by 'James Gunn', & 'Ridley Scott'.**

# %%
data[data['Director'] == 'James Gunn']
# Out:
#      Rank                    Title                    Genre  \
# 0       1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
# 908   909                  Slither     Comedy,Horror,Sci-Fi
# 937   938                    Super             Comedy,Drama
#
#                                            Description    Director  \
# 0    A group of intergalactic criminals are forced ...  James Gunn
# 908  A small town is taken over by an alien plague,...  James Gunn
# 937  After his wife falls under the influence of a ...  James Gunn
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 908  Nathan Fillion, Elizabeth Banks, Michael Rooke...  2006
# 937   Rainn Wilson, Ellen Page, Liv Tyler, Kevin Bacon  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue  Metascore
# 0                  121     8.1  757074   333.13       76.0
# 908                 95     6.5   64351     7.77       69.0
# 937                 96     6.8   64535     0.32       50.0

# %%
data[data['Director'] == 'Ridley Scott']
# Out:
#      Rank                   Title                     Genre  \
# 1       2              Prometheus  Adventure,Mystery,Sci-Fi
# 102   103             The Martian    Adventure,Drama,Sci-Fi
# 387   388              Robin Hood    Action,Adventure,Drama
# 470   471       American Gangster     Biography,Crime,Drama
# 516   517  Exodus: Gods and Kings    Action,Adventure,Drama
# 521   522           The Counselor      Crime,Drama,Thriller
# 530   531             A Good Year      Comedy,Drama,Romance
# 737   738            Body of Lies      Action,Drama,Romance
#
#                                            Description      Director  \
# 1    Following clues to the origin of mankind, a te...  Ridley Scott
# 102  An astronaut becomes stranded on Mars after hi...  Ridley Scott
# 387  In 12th century England, Robin and his band of...  Ridley Scott
# 470  In 1970s America, a detective works to bring d...  Ridley Scott
# 516  The defiant leader Moses rises up against the ...  Ridley Scott
# 521  A lawyer finds himself in over his head when h...  Ridley Scott
# 530  A British investment broker inherits his uncle...  Ridley Scott
# 737  A CIA agent on the ground in Jordan hunts down...  Ridley Scott
#
#                                                 Actors  Year  \
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# 102  Matt Damon, Jessica Chastain, Kristen Wiig, Ka...  2015
# 387  Russell Crowe, Cate Blanchett, Matthew Macfady...  2010
# 470  Denzel Washington, Russell Crowe, Chiwetel Eji...  2007
# 516  Christian Bale, Joel Edgerton, Ben Kingsley, S...  2014
# 521  Michael Fassbender, Penélope Cruz, Cameron Dia...  2013
# 530  Russell Crowe, Abbie Cornish, Albert Finney, M...  2006
# 737  Leonardo DiCaprio, Russell Crowe, Mark Strong,...  2008
#
#      Runtime (Minutes)  Rating   Votes  Revenue  Metascore
# 1                  124     7.0  485820   126.46       65.0
# 102                144     8.0  556097   228.43       80.0
# 387                140     6.7  221117   105.22       53.0
# 470                157     7.8  337835   130.13       76.0
# 516                150     6.0  137299    65.01       52.0
# 521                117     5.3   84927    16.97       48.0
# 530                117     6.9   74674     7.46       47.0
# 737                128     7.1  182305    39.38       57.0

# %%
data[(data['Director'] == 'James Gunn') | (data['Director'] == 'Ridley Scott')]
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 102   103              The Martian    Adventure,Drama,Sci-Fi
# 387   388               Robin Hood    Action,Adventure,Drama
# 470   471        American Gangster     Biography,Crime,Drama
# 516   517   Exodus: Gods and Kings    Action,Adventure,Drama
# 521   522            The Counselor      Crime,Drama,Thriller
# 530   531              A Good Year      Comedy,Drama,Romance
# 737   738             Body of Lies      Action,Drama,Romance
# 908   909                  Slither      Comedy,Horror,Sci-Fi
# 937   938                    Super              Comedy,Drama
#
#                                            Description      Director  \
# 0    A group of intergalactic criminals are forced ...    James Gunn
# 1    Following clues to the origin of mankind, a te...  Ridley Scott
# 102  An astronaut becomes stranded on Mars after hi...  Ridley Scott
# 387  In 12th century England, Robin and his band of...  Ridley Scott
# 470  In 1970s America, a detective works to bring d...  Ridley Scott
# 516  The defiant leader Moses rises up against the ...  Ridley Scott
# 521  A lawyer finds himself in over his head when h...  Ridley Scott
# 530  A British investment broker inherits his uncle...  Ridley Scott
# 737  A CIA agent on the ground in Jordan hunts down...  Ridley Scott
# 908  A small town is taken over by an alien plague,...    James Gunn
# 937  After his wife falls under the influence of a ...    James Gunn
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# 102  Matt Damon, Jessica Chastain, Kristen Wiig, Ka...  2015
# 387  Russell Crowe, Cate Blanchett, Matthew Macfady...  2010
# 470  Denzel Washington, Russell Crowe, Chiwetel Eji...  2007
# 516  Christian Bale, Joel Edgerton, Ben Kingsley, S...  2014
# 521  Michael Fassbender, Penélope Cruz, Cameron Dia...  2013
# 530  Russell Crowe, Abbie Cornish, Albert Finney, M...  2006
# 737  Leonardo DiCaprio, Russell Crowe, Mark Strong,...  2008
# 908  Nathan Fillion, Elizabeth Banks, Michael Rooke...  2006
# 937   Rainn Wilson, Ellen Page, Liv Tyler, Kevin Bacon  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue  Metascore
# 0                  121     8.1  757074   333.13       76.0
# 1                  124     7.0  485820   126.46       65.0
# 102                144     8.0  556097   228.43       80.0
# 387                140     6.7  221117   105.22       53.0
# 470                157     7.8  337835   130.13       76.0
# 516                150     6.0  137299    65.01       52.0
# 521                117     5.3   84927    16.97       48.0
# 530                117     6.9   74674     7.46       47.0
# 737                128     7.1  182305    39.38       57.0
# 908                 95     6.5   64351     7.77       69.0
# 937                 96     6.8   64535     0.32       50.0

# %% [markdown]
# **Display all the movies with the ratings between 8 & 9 and also the films with the highest rating.**

# %%
cond = (data['Rating'] >= 8) & (data['Rating'] <= 8)

# %%
data[cond]
# Out:
#      Rank                            Title                      Genre  \
# 19     20                          Arrival       Drama,Mystery,Sci-Fi
# 33     34                         Deadpool    Action,Adventure,Comedy
# 102   103                      The Martian     Adventure,Drama,Sci-Fi
# 129   130                     The Revenant   Adventure,Drama,Thriller
# 140   141                        Star Trek    Action,Adventure,Sci-Fi
# 162   163       X-Men: Days of Future Past    Action,Adventure,Sci-Fi
# 164   165                    Casino Royale  Action,Adventure,Thriller
# 173   174                              Her       Drama,Romance,Sci-Fi
# 184   185                       Forushande             Drama,Thriller
# 235   236  The Perks of Being a Wallflower              Drama,Romance
# 261   262                       Black Swan             Drama,Thriller
# 273   274                      Sing Street         Comedy,Drama,Music
# 332   333               Dallas Buyers Club            Biography,Drama
# 365   366              Slumdog Millionaire                      Drama
# 468   469                       District 9     Action,Sci-Fi,Thriller
# 489   490                      Ratatouille    Animation,Comedy,Family
# 640   641         The Pursuit of Happyness            Biography,Drama
# 669   670                    Blood Diamond   Adventure,Drama,Thriller
# 685   686                The King's Speech            Biography,Drama
#
#                                            Description  \
# 19   When twelve mysterious spacecraft appear aroun...
# 33   A fast-talking mercenary with a morbid sense o...
# 102  An astronaut becomes stranded on Mars after hi...
# 129  A frontiersman on a fur trading expedition in ...
# 140  The brash James T. Kirk tries to live up to hi...
# 162  The X-Men send Wolverine to the past in a desp...
# 164  Armed with a licence to kill, Secret Agent Jam...
# 173  A lonely writer develops an unlikely relations...
# 184  While both participating in a production of "D...
# 235  An introvert freshman is taken under the wings...
# 261  A committed dancer wins the lead role in a pro...
# 273  A boy growing up in Dublin during the 1980s es...
# 332  In 1985 Dallas, electrician and hustler Ron Wo...
# 365  A Mumbai teen reflects on his upbringing in th...
# 468  An extraterrestrial race forced to live in slu...
# 489  A rat who can cook makes an unusual alliance w...
# 640  A struggling salesman takes custody of his son...
# 669  A fisherman, a smuggler, and a syndicate of bu...
# 685  The story of King George VI of the United King...
#
#                         Director  \
# 19              Denis Villeneuve
# 33                    Tim Miller
# 102                 Ridley Scott
# 129  Alejandro González Iñárritu
# 140                  J.J. Abrams
# 162                 Bryan Singer
# 164              Martin Campbell
# 173                  Spike Jonze
# 184               Asghar Farhadi
# 235              Stephen Chbosky
# 261             Darren Aronofsky
# 273                  John Carney
# 332             Jean-Marc Vallée
# 365                  Danny Boyle
# 468               Neill Blomkamp
# 489                    Brad Bird
# 640             Gabriele Muccino
# 669                 Edward Zwick
# 685                   Tom Hooper
#
#                                                 Actors  Year  \
# 19   Amy Adams, Jeremy Renner, Forest Whitaker,Mich...  2016
# 33   Ryan Reynolds, Morena Baccarin, T.J. Miller, E...  2016
# 102  Matt Damon, Jessica Chastain, Kristen Wiig, Ka...  2015
# 129  Leonardo DiCaprio, Tom Hardy, Will Poulter, Do...  2015
# 140  Chris Pine, Zachary Quinto, Simon Pegg, Leonar...  2009
# 162  Patrick Stewart, Ian McKellen, Hugh Jackman, J...  2014
# 164  Daniel Craig, Eva Green, Judi Dench, Jeffrey W...  2006
# 173  Joaquin Phoenix, Amy Adams, Scarlett Johansson...  2013
# 184  Taraneh Alidoosti, Shahab Hosseini, Babak Kari...  2016
# 235  Logan Lerman, Emma Watson, Ezra Miller, Paul Rudd  2012
# 261  Natalie Portman, Mila Kunis, Vincent Cassel,Wi...  2010
# 273  Ferdia Walsh-Peelo, Aidan Gillen, Maria Doyle ...  2016
# 332  Matthew McConaughey, Jennifer Garner, Jared Le...  2013
# 365  Dev Patel, Freida Pinto, Saurabh Shukla, Anil ...  2008
# 468  Sharlto Copley, David James, Jason Cope, Natha...  2009
# 489   Brad Garrett, Lou Romano, Patton Oswalt,Ian Holm  2007
# 640  Will Smith, Thandie Newton, Jaden Smith, Brian...  2006
# 669  Leonardo DiCaprio, Djimon Hounsou, Jennifer Co...  2006
# 685  Colin Firth, Geoffrey Rush, Helena Bonham Cart...  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue  Metascore
# 19                 116     8.0  340798   100.50       81.0
# 33                 108     8.0  627797   363.02       65.0
# 102                144     8.0  556097   228.43       80.0
# 129                156     8.0  499424   183.64       76.0
# 140                127     8.0  526324   257.70       82.0
# 162                132     8.0  552298   233.91       74.0
# 164                144     8.0  495106   167.01       80.0
# 173                126     8.0  390531    25.56       90.0
# 184                124     8.0   22389     3.40       85.0
# 235                102     8.0  377336    17.74       67.0
# 261                108     8.0  581518   106.95       79.0
# 273                106     8.0   52144     3.23       79.0
# 332                117     8.0  352801    27.30       84.0
# 365                120     8.0  677044   141.32       86.0
# 468                112     8.0  556794   115.65       81.0
# 489                111     8.0  504039   206.44       96.0
# 640                117     8.0  361105   162.59       64.0
# 669                143     8.0  422014    57.37       64.0
# 685                118     8.0  534388   138.80       88.0

# %%
data[ data['Rating'] == data['Rating'].max()]
# Out:
#     Rank            Title               Genre  \
# 54    55  The Dark Knight  Action,Crime,Drama
#
#                                           Description           Director  \
# 54  When the menace known as the Joker wreaks havo...  Christopher Nolan
#
#                                                Actors  Year  \
# 54  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
#
#     Runtime (Minutes)  Rating    Votes  Revenue  Metascore
# 54                152     9.0  1791916   533.32       82.0

# %% [markdown]
# **Find the movies directed by both 'Christopher Nolan' and 'Ridley Scott'**

# %%
data[data['Director'].isin(['Christopher Nolan', 'Ridley Scott'])]
# Out:
#      Rank                   Title                     Genre  \
# 1       2              Prometheus  Adventure,Mystery,Sci-Fi
# 36     37            Interstellar    Adventure,Drama,Sci-Fi
# 54     55         The Dark Knight        Action,Crime,Drama
# 64     65            The Prestige      Drama,Mystery,Sci-Fi
# 80     81               Inception   Action,Adventure,Sci-Fi
# 102   103             The Martian    Adventure,Drama,Sci-Fi
# 124   125   The Dark Knight Rises           Action,Thriller
# 387   388              Robin Hood    Action,Adventure,Drama
# 470   471       American Gangster     Biography,Crime,Drama
# 516   517  Exodus: Gods and Kings    Action,Adventure,Drama
# 521   522           The Counselor      Crime,Drama,Thriller
# 530   531             A Good Year      Comedy,Drama,Romance
# 737   738            Body of Lies      Action,Drama,Romance
#
#                                            Description           Director  \
# 1    Following clues to the origin of mankind, a te...       Ridley Scott
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 64   Two stage magicians engage in competitive one-...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 102  An astronaut becomes stranded on Mars after hi...       Ridley Scott
# 124  Eight years after the Joker's reign of anarchy...  Christopher Nolan
# 387  In 12th century England, Robin and his band of...       Ridley Scott
# 470  In 1970s America, a detective works to bring d...       Ridley Scott
# 516  The defiant leader Moses rises up against the ...       Ridley Scott
# 521  A lawyer finds himself in over his head when h...       Ridley Scott
# 530  A British investment broker inherits his uncle...       Ridley Scott
# 737  A CIA agent on the ground in Jordan hunts down...       Ridley Scott
#
#                                                 Actors  Year  \
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# 36   Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 64   Christian Bale, Hugh Jackman, Scarlett Johanss...  2006
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# 102  Matt Damon, Jessica Chastain, Kristen Wiig, Ka...  2015
# 124  Christian Bale, Tom Hardy, Anne Hathaway,Gary ...  2012
# 387  Russell Crowe, Cate Blanchett, Matthew Macfady...  2010
# 470  Denzel Washington, Russell Crowe, Chiwetel Eji...  2007
# 516  Christian Bale, Joel Edgerton, Ben Kingsley, S...  2014
# 521  Michael Fassbender, Penélope Cruz, Cameron Dia...  2013
# 530  Russell Crowe, Abbie Cornish, Albert Finney, M...  2006
# 737  Leonardo DiCaprio, Russell Crowe, Mark Strong,...  2008
#
#      Runtime (Minutes)  Rating    Votes  Revenue  Metascore
# 1                  124     7.0   485820   126.46       65.0
# 36                 169     8.6  1047747   187.99       74.0
# 54                 152     9.0  1791916   533.32       82.0
# 64                 130     8.5   913152    53.08       66.0
# 80                 148     8.8  1583625   292.57       74.0
# 102                144     8.0   556097   228.43       80.0
# 124                164     8.5  1222645   448.13       78.0
# 387                140     6.7   221117   105.22       53.0
# 470                157     7.8   337835   130.13       76.0
# 516                150     6.0   137299    65.01       52.0
# 521                117     5.3    84927    16.97       48.0
# 530                117     6.9    74674     7.46       47.0
# 737                128     7.1   182305    39.38       57.0

# %% [markdown]
# **Find all movies that were released between 2006 and 2010, have a rating above 8.0, but made below the 50th percentile in revenue.**

# %%
dataC = data[(data['Rating'] > 8) & (data['Revenue'] < data['Revenue'].quantile(0.5))]
condition = (data['Year'] >= 2006) & (data['Year'] <= 2010)

# %%
dataC[condition]
# Out:
# <ipython-input-66-374e5dd95fb8>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataC[condition]
#      Rank                   Title                      Genre  \
# 197   198           Into the Wild  Adventure,Biography,Drama
# 230   231         Pan's Labyrinth          Drama,Fantasy,War
# 299   300     There Will Be Blood              Drama,History
# 430   431                3 Idiots               Comedy,Drama
# 476   477     The Lives of Others             Drama,Thriller
# 713   714               Incendies          Drama,Mystery,War
# 742   743  El secreto de sus ojos      Drama,Mystery,Romance
# 991   992        Taare Zameen Par         Drama,Family,Music
#
#                                            Description  \
# 197  After graduating from Emory University, top st...
# 230  In the falangist Spain of 1944, the bookish yo...
# 299  A story of family, religion, hatred, oil and m...
# 430  Two friends are searching for their long lost ...
# 476  In 1984 East Berlin, an agent of the secret po...
# 713  Twins journey to the Middle East to discover t...
# 742  A retired legal counselor writes a novel hopin...
# 991  An eight-year-old boy is thought to be a lazy ...
#
#                              Director  \
# 197                         Sean Penn
# 230                Guillermo del Toro
# 299              Paul Thomas Anderson
# 430                   Rajkumar Hirani
# 476  Florian Henckel von Donnersmarck
# 713                  Denis Villeneuve
# 742              Juan José Campanella
# 991                        Aamir Khan
#
#                                                 Actors  Year  \
# 197  Emile Hirsch, Vince Vaughn, Catherine Keener, ...  2007
# 230  Ivana Baquero, Ariadna Gil, Sergi López,Maribe...  2006
# 299  Daniel Day-Lewis, Paul Dano, Ciarán Hinds,Mart...  2007
# 430    Aamir Khan, Madhavan, Mona Singh, Sharman Joshi  2009
# 476  Ulrich Mühe, Martina Gedeck,Sebastian Koch, Ul...  2006
# 713  Lubna Azabal, Mélissa Désormeaux-Poulin, Maxim...  2010
# 742  Ricardo Darín, Soledad Villamil, Pablo Rago,Ca...  2009
# 991  Darsheel Safary, Aamir Khan, Tanay Chheda, Sac...  2007
#
#      Runtime (Minutes)  Rating   Votes  Revenue  Metascore
# 197                148     8.1  459304    18.35       73.0
# 230                118     8.2  498879    37.62       98.0
# 299                158     8.1  400682    40.22       92.0
# 430                170     8.4  238789     6.52       67.0
# 476                137     8.5  278103    11.28       89.0
# 713                131     8.2   92863     6.86       80.0
# 742                129     8.2  144524    20.17       80.0
# 991                165     8.5  102697     1.20       42.0

# %% [markdown]
# **Find all movies that were released between 2006 and 2010, have a rating above 8.0, but made below the 25th percentile in revenue.**

# %%
dataD = data[(data['Rating'] > 8) & (data['Revenue'] < data['Revenue'].quantile(0.25))]

# %%
dataD[condition]
# Out:
# <ipython-input-69-a626c5133705>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dataD[condition]
#      Rank                Title               Genre  \
# 430   431             3 Idiots        Comedy,Drama
# 476   477  The Lives of Others      Drama,Thriller
# 713   714            Incendies   Drama,Mystery,War
# 991   992     Taare Zameen Par  Drama,Family,Music
#
#                                            Description  \
# 430  Two friends are searching for their long lost ...
# 476  In 1984 East Berlin, an agent of the secret po...
# 713  Twins journey to the Middle East to discover t...
# 991  An eight-year-old boy is thought to be a lazy ...
#
#                              Director  \
# 430                   Rajkumar Hirani
# 476  Florian Henckel von Donnersmarck
# 713                  Denis Villeneuve
# 991                        Aamir Khan
#
#                                                 Actors  Year  \
# 430    Aamir Khan, Madhavan, Mona Singh, Sharman Joshi  2009
# 476  Ulrich Mühe, Martina Gedeck,Sebastian Koch, Ul...  2006
# 713  Lubna Azabal, Mélissa Désormeaux-Poulin, Maxim...  2010
# 991  Darsheel Safary, Aamir Khan, Tanay Chheda, Sac...  2007
#
#      Runtime (Minutes)  Rating   Votes  Revenue  Metascore
# 430                170     8.4  238789     6.52       67.0
# 476                137     8.5  278103    11.28       89.0
# 713                131     8.2   92863     6.86       80.0
# 991                165     8.5  102697     1.20       42.0

# %% [markdown]
# **Finally give the feedback for all movies with 'Good' if the movie 'rating' is >= 8 and 'Average' if the movie rating doesn't follow the condition given.**

# %%
def movie_qual(x):
  if x >= 8:
    return 'Good'
  else:
    return 'Average'

# %%
data['Rating'] = data['Rating'].apply(movie_qual)

# %%
data.head(2)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
#
#     Rating   Votes  Revenue  Metascore
# 0     Good  757074   333.13       76.0
# 1  Average  485820   126.46       65.0
